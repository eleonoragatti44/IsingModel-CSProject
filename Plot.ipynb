# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# parameters for plots
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
#mpl.rcParams['axes.position.left'] = 'center'
#ax.spines['bottom'].set_position('center')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-5b321fc0c870> in <module>
#      13 mpl.rcParams['axes.spines.top'] = False
#      14 #mpl.rcParams['axes.position.left'] = 'center'
# ---> 15 mpl.spines['left'].set_position('center')
#      16 #ax.spines['bottom'].set_position('center')
#
# TypeError: 'module' object is not subscriptable

# %%
x = np.linspace(-1.5,1.5,1000)
y1 = np.tanh(0.7*x)
y2 = np.tanh(1.7*x)
y3 = np.tanh(x)

plt.plot(x, x)
plt.plot(x, y1, label='$\gamma$ J \u03B2 < 1')
plt.plot(x, y2, label='$\gamma$ J \u03B2 > 1')
plt.plot(x, y3, label='$\gamma$ J \u03B2 = 1')
plt.legend()

plt.savefig('fig/mf_graph_sol.pdf', dpi=400)
